# %%
import pandas as pd

# %%
mvp_candidates = pd.read_excel(
    "/Users/anoosha/Projects/Public Github Repos/Data-Analysis-Projects-2-Basketball/data/new_mvp_candidates.xlsx"
)

# %%
mvp_candidates
# Out:
#     Year Rank  Player_Id  Age Team  First_Place_Vote  Pts Won  pts Max  Share  \
# 0   2019    1  antetgi01   24  MIL                78      941     1010  0.932
# 1   2019    2  hardeja01   29  HOU                23      776     1010  0.768
# 2   2019    3  georgpa01   28  OKC                 0      356     1010  0.352
# 3   2019    4  jokicni01   23  DEN                 0      212     1010  0.210
# 4   2019    5  curryst01   30  GSW                 0      175     1010  0.173
# ..   ...  ...        ...  ...  ...               ...      ...      ...    ...
# 80  2025   7T  edwaran01   23  MIN                 0       12     1000  0.012
# 81  2025    9  curryst01   36  GSW                 0        2     1000  0.002
# 82  2025  10T  brunsja01   28  NYK                 0        1     1000  0.001
# 83  2025  10T  hardeja01   35  LAC                 0        1     1000  0.001
# 84  2025  10T  mobleev01   23  CLE                 0        1     1000  0.001
#
# ...

# %%
mvp_candidates.columns = mvp_candidates.columns.str.lower()

# %%
mvp_candidates_col_names = {
    "first_place_vote": "first_place_votes",
    "pts won": "points_won",
    "pts max": "points_max",
    "fg%": "fg_pct",
    "3p%": "three_pct",
    "ft%": "ft_pct",
    "ws/48": "ws_per_48"
}

# %%
mvp_candidates = mvp_candidates.rename(columns=mvp_candidates_col_names)

# %%
mvp_candidates[['year','player_id']].duplicated().sum()
##this pair is our composite key
# Out:
# np.int64(0)

# %%
split_t = mvp_candidates['rank'].str.strip().str.extract(r'(\d+)(T?)')

# %%
split_t
# Out:
#      0  1
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# ..  .. ..
# 80   7  T
# 81   9
# 82  10  T
# 83  10  T
# 84  10  T
#
# [85 rows x 2 columns]

# %%
split_t[1]= split_t[1].astype(bool)

# %%
split_t
# Out:
#      0      1
# 0    1  False
# 1    2  False
# 2    3  False
# 3    4  False
# 4    5  False
# ..  ..    ...
# 80   7   True
# 81   9  False
# 82  10   True
# 83  10   True
# 84  10   True
#
# [85 rows x 2 columns]

# %%
mvp_candidates
# Out:
#     year rank  player_id  age team  first_place_votes  points_won  points_max  \
# 0   2019    1  antetgi01   24  MIL                 78         941        1010
# 1   2019    2  hardeja01   29  HOU                 23         776        1010
# 2   2019    3  georgpa01   28  OKC                  0         356        1010
# 3   2019    4  jokicni01   23  DEN                  0         212        1010
# 4   2019    5  curryst01   30  GSW                  0         175        1010
# ..   ...  ...        ...  ...  ...                ...         ...         ...
# 80  2025   7T  edwaran01   23  MIN                  0          12        1000
# 81  2025    9  curryst01   36  GSW                  0           2        1000
# 82  2025  10T  brunsja01   28  NYK                  0           1        1000
# 83  2025  10T  hardeja01   35  LAC                  0           1        1000
# 84  2025  10T  mobleev01   23  CLE                  0           1        1000
#
# ...

# %%
mvp_candidates[['rank','tie']] = split_t[[0,1]].values

# %%
mvp_candidates
# Out:
#     year rank  player_id  age team  first_place_votes  points_won  points_max  \
# 0   2019    1  antetgi01   24  MIL                 78         941        1010
# 1   2019    2  hardeja01   29  HOU                 23         776        1010
# 2   2019    3  georgpa01   28  OKC                  0         356        1010
# 3   2019    4  jokicni01   23  DEN                  0         212        1010
# 4   2019    5  curryst01   30  GSW                  0         175        1010
# ..   ...  ...        ...  ...  ...                ...         ...         ...
# 80  2025    7  edwaran01   23  MIN                  0          12        1000
# 81  2025    9  curryst01   36  GSW                  0           2        1000
# 82  2025   10  brunsja01   28  NYK                  0           1        1000
# 83  2025   10  hardeja01   35  LAC                  0           1        1000
# 84  2025   10  mobleev01   23  CLE                  0           1        1000
#
# ...

# %%
mvp_candidates.columns
# Out:
# Index(['year', 'rank', 'player_id', 'age', 'team', 'first_place_votes',
#        'points_won', 'points_max', 'share', 'games', 'mp', 'pts', 'trb', 'ast',
#        'stl', 'blk', 'fg_pct', 'three_pct', 'ft_pct', 'ws', 'ws_per_48',
#        'tie'],
#       dtype='object')

# %%
mvp_candidates_col_order = [
    "year",
    "player_id",
    "rank",
    "tie",
    "age",
    "team",
    "first_place_votes",
    "points_won",
    "points_max",
    "share",
    "games",
    "mp",
    "pts",
    "trb",
    "ast",
    "stl",
    "blk",
    "fg_pct",
    "three_pct",
    "ft_pct",
    "ws",
    "ws_per_48",
]

# %%
mvp_candidates = mvp_candidates[mvp_candidates_col_order]

# %%
mvp_candidates
# Out:
#     year  player_id rank    tie  age team  first_place_votes  points_won  \
# 0   2019  antetgi01    1  False   24  MIL                 78         941
# 1   2019  hardeja01    2  False   29  HOU                 23         776
# 2   2019  georgpa01    3  False   28  OKC                  0         356
# 3   2019  jokicni01    4  False   23  DEN                  0         212
# 4   2019  curryst01    5  False   30  GSW                  0         175
# ..   ...        ...  ...    ...  ...  ...                ...         ...
# 80  2025  edwaran01    7   True   23  MIN                  0          12
# 81  2025  curryst01    9  False   36  GSW                  0           2
# 82  2025  brunsja01   10   True   28  NYK                  0           1
# 83  2025  hardeja01   10   True   35  LAC                  0           1
# 84  2025  mobleev01   10   True   23  CLE                  0           1
#
#     points_max  share  ...   pts   trb  ast  stl  blk  fg_pct  three_pct  \
# ...

# %%
mvp_candidates.dtypes
# Out:
# year                   int64
# player_id             object
# rank                  object
# tie                   object
# age                    int64
# team                  object
# first_place_votes      int64
# points_won             int64
# points_max             int64
# share                float64
# games                  int64
# mp                   float64
# pts                  float64
# trb                  float64
# ast                  float64
# stl                  float64
# blk                  float64
# fg_pct               float64
# three_pct            float64
# ft_pct               float64
# ws                   float64
# ws_per_48            float64
# dtype: object

# %%
mvp_candidates['rank']=mvp_candidates['rank'].astype('int64')

# %%
mvp_candidates['tie']= mvp_candidates['tie'].astype(bool)

# %%
mvp_candidates.dtypes
# Out:
# year                   int64
# player_id             object
# rank                   int64
# tie                     bool
# age                    int64
# team                  object
# first_place_votes      int64
# points_won             int64
# points_max             int64
# share                float64
# games                  int64
# mp                   float64
# pts                  float64
# trb                  float64
# ast                  float64
# stl                  float64
# blk                  float64
# fg_pct               float64
# three_pct            float64
# ft_pct               float64
# ws                   float64
# ws_per_48            float64
# dtype: object
