# %%
# %load_ext autoreload
# %autoreload 2


from Scraper import BasketballScraper

import importlib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
main = BasketballScraper(headers={
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                    "(KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
        "Connection": "keep-alive",
        "Upgrade-Insecure-Requests": "1",
        "Referer": "https://google.com/",
        "Sec-Fetch-Site": "same-origin",
        "Sec-Fetch-Mode": "navigate",
        "Sec-Fetch-User": "?1",
        "Sec-Fetch-Dest": "document"
    },way=1)
# Out:
# All packages already installed: tqdm, webdriver_manager
# Teams Temp: 100%|██████████| 121/121 [00:00<00:00, 13900.60it/s]
# [SUCCESS] temp/teams_link.csv saved.
# Seasons Temp:  68%|██████▊   | 161/238 [00:00<00:00, 16989.10it/s]
# [SUCCESS] temp/seasons_link.csv saved.

# %%
main.all_teams_detail()
# Out:
# Links: 100%|██████████| 119/119 [02:41<00:00,  1.36s/it]
# [SUCCESS] data/teams.csv saved.
# [{'link': 'https://www.basketball-reference.com/teams/OKC',
#   'team_full_name': 'Oklahoma City Thunder',
#   'location': 'Oklahoma City, Oklahoma',
#   'team_names': 'Oklahoma City Thunder, Seattle SuperSonics',
#   'seasons': '59; 1967-68 to 2025-26',
#   'seasons_count': 59,
#   'seasons_range': '1967-68 to 2025-26',
#   'record': '2538-2150, .541 W-L%',
#   'playoff_appearances': 34,
#   'championships': 2},
#  {'link': 'https://www.basketball-reference.com/teams/BOS',
#   'team_full_name': 'Boston Celtics',
#   'location': 'Boston, Massachusetts',
#   'team_names': 'Boston Celtics',
#   'seasons': '80; 1946-47 to 2025-26',
#   'seasons_count': 80,
#   'seasons_range': '1946-47 to 2025-26',
#   'record': '3695-2501, .596 W-L%',
#   'playoff_appearances': 62,
#   'championships': 18},
#  {'link': 'https://www.basketball-reference.com/teams/DEN',
#   'team_full_name': 'Denver Nuggets',
# ...

# %%
main.all_teams_seasons_detail()
# Out:
# Links: 100%|██████████| 119/119 [06:58<00:00,  3.52s/it]
# [SUCCESS] data/teams_seasons.csv saved.
# [{'link': 'https://www.basketball-reference.com/teams/OKC/2025.html',
#   'team_full_name': 'Oklahoma City Thunder',
#   'season': '2024-25',
#   'record': '68-14, Finished 1st in NBA Western Conference',
#   'coach': 'Mark Daigneault (68-14)',
#   'executive': 'Sam Presti',
#   'pts_g': '120.5 (4th of 30) Opp PTS/G: 107.6 (3rd of 30)',
#   'srs': '12.70 (1st of 30) Pace : 100.0 (6th of 30)',
#   'off_rtg': '120.3 (3rd of 30) Def Rtg : 107.5 (1st of 30) Net Rtg : +12.8 (1st of 30)',
#   'expected_w_l': '68-14 (1st of 30)',
#   'preseason_odds': 'Championship +675 , Over-Under 57.5',
#   'arena': 'Paycom Center Attendance: 754,832 (14th of 30)'},
#  {'link': 'https://www.basketball-reference.com/teams/BOS/2024.html',
#   'team_full_name': 'Boston Celtics',
#   'season': '2023-24',
#   'record': '64-18, Finished 1st in NBA Eastern Conference',
#   'coach': 'Joe Mazzulla (64-18)',
# ...

# %%
main.all_team_seasons_roasters()
# Out:
# Links: 100%|██████████| 119/119 [08:14<00:00,  4.16s/it]
# [SUCCESS] data/teams_seasons_rosters_clean.csv saved.
# [{'TeamName': 'Oklahoma City Thunder',
#   'Season': '2024-25',
#   'PlayerName': ['Branden Carlson'],
#   'Player_id': ['carlsbr01'],
#   'Team_id': 'OKC',
#   'Pos': ['C'],
#   'Ht': ['7-0'],
#   'Wt': ['220'],
#   'Birth Date': ['June 14, 1999'],
#   'Birth': ['us US'],
#   'Exp': ['R'],
#   'College': ['Utah']},
#  {'TeamName': 'Oklahoma City Thunder',
#   'Season': '2024-25',
#   'PlayerName': ['Alex Caruso'],
#   'Player_id': ['carusal01'],
#   'Team_id': 'OKC',
#   'Pos': ['SG'],
#   'Ht': ['6-5'],
#   'Wt': ['186'],
#   'Birth Date': ['February 28, 1994'],
#   'Birth': ['us US'],
#   'Exp': ['7'],
#   'College': ['Texas A&M']},
#  {'TeamName': 'Oklahoma City Thunder',
#   'Season': '2024-25',
#   'PlayerName': ['Ousmane Dieng'],
#   'Player_id': ['diengou01'],
#   'Team_id': 'OKC',
#   'Pos': ['C'],
#   'Ht': ['6-10'],
#   'Wt': ['222'],
# ...

# %%
main.all_seasons_total_stats()
# Out:
# Links:   0%|          | 0/161 [00:00<?, ?it/s]
# [WARN] Request failed (('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))). Retrying in 3.5s (attempt 1)
# [ERROR] Failed to fetch https://www.basketball-reference.com/leagues/NBA_2026.html after 5 attempts.
# ...
# Links: 100%|██████████| 161/161 [18:27<00:00,  6.88s/it]
# [SUCCESS] data/seasons_teams_total_stats.csv saved.
# [{'Rk': ['1'],
#   'Season': '2025-26',
#   'TeamName': ['Miami Heat'],
#   'TeamId': ['MIA'],
#   'G': ['0'],
#   'MP': ['0'],
#   'FG': ['0'],
#   'FGA': ['0'],
#   'FG%': [''],
#   '3P': ['0'],
#   '3PA': ['0'],
#   '3P%': [''],
#   '2P': ['0'],
#   '2PA': ['0'],
#   '2P%': [''],
#   'FT': ['0'],
#   'FTA': ['0'],
#   'FT%': [''],
#   'ORB': ['0'],
#   'DRB': ['0'],
#   'TRB': ['0'],
#   'AST': ['0'],
#   'STL': ['0'],
#   'BLK': ['0'],
#   'TOV': ['0'],
#   'PF': ['0'],
#   'PTS': ['0']},
#  {'Rk': ['2'],
#   'Season': '2025-26',
#   'TeamName': ['Washington Wizards'],
# ...

# %%
main.all_mvp_candidate(base_url='https://www.basketball-reference.com/awards/awards_')
# Out:
# Links: 100%|██████████| 7/7 [00:30<00:00,  4.40s/it]
# [SUCCESS] data/mvp_candidates.csv saved.

# %%
main.all_player_stats(base_url='https://www.basketball-reference.com/leagues/NBA_')
# Out:
# Links: 100%|██████████| 7/7 [00:43<00:00,  6.21s/it]
# [SUCCESS] data/player_stats.csv saved.

# %%
# %reload_ext autoreload
main.seasons_details()
# Out:
# Links:  98%|█████████▊| 89/91 [00:00<00:00, 553.85it/s]
# [SUCCESS] data/seasons_table.csv saved.

# %%
# %reload_ext autoreload
main.all_advanced_stats(base_url='https://www.basketball-reference.com/leagues/NBA_')
# Out:
# Links: 100%|██████████| 7/7 [00:56<00:00,  8.12s/it]
# [SUCCESS] data/Advanced_stats.csv saved.

# %%
# %reload_ext autoreload
main.players()
# Out:
# [SUCCESS] data/Players_table.csv saved.
# [{'player_id': 'gilgesh01',
#   'player_name': ['Shai Gilgeous-Alexander'],
#   'Position': '\n  \n  Point Guard and Shooting Guard',
#   'Shoots': 'Right',
#   'Height': '6-6',
#   'Weight': '200',
#   'Birthday': '12',
#   'Birthmonth': 'July',
#   'Birthyear': ['1998'],
#   'College': ['Kentucky'],
#   'Last Season Games': ['76'],
#   'Last Season Points': ['32.7'],
#   'Last Season Total Rebound Percentage': ['5.0'],
#   'Last Season Assists Percentage': ['6.4'],
#   'Last Season Field Goal Percentage': ['76'],
#   'Last Season 3pt Field Goal Percentage': ['32.7'],
#   'Last Season TFree Throw Percentage': ['5.0'],
#   'Last Season Effective Field Goal Percentage': ['6.4'],
#   'Experience': '7',
#   'Career Games': ['462'],
#   'Career Points': ['24.4'],
#   'Career Total Rebound Percentage': ['4.8'],
#   'Career Assists Percentage': ['5.1'],
#   'Career Field Goal Percentage': ['50.1'],
#   'Career 3pt Field Goal Percentage': ['35.5'],
# ...

# %%
# %reload_ext autoreload
main.mvps()
# Out:
# [SUCCESS] data/Mvp_table.csv saved.
# [{'Season': ['2024-25'],
#   'League': 'NBA',
#   'Player_id': 'gilgesh01',
#   'Age': ['26'],
#   'Team_id': ['OKC'],
#   'Game': ['76'],
#   'Minutes Played Per Game': ['34.2'],
#   'Points Per Game': ['32.7'],
#   'Total Rebounds Per Game': ['5.0'],
#   'Assists Per Game': ['6.4'],
#   'Steals Per Game': ['1.7'],
#   'Blocks Per Game': ['1.0'],
#   'Field Goal Percentage': ['.519'],
#   '3-Point Field Goal Percentage': ['.375'],
#   'Free Throw Percentage': ['.898'],
#   'Win Shares': ['16.7'],
#   'Win Shares Per 48 Minutes': ['.309']},
#  {'Season': ['2023-24'],
#   'League': 'NBA',
#   'Player_id': 'jokicni01',
#   'Age': ['28'],
#   'Team_id': ['DEN'],
#   'Game': ['79'],
#   'Minutes Played Per Game': ['34.6'],
#   'Points Per Game': ['26.4'],
#   'Total Rebounds Per Game': ['12.4'],
#   'Assists Per Game': ['9.0'],
#   'Steals Per Game': ['1.4'],
#   'Blocks Per Game': ['0.9'],
#   'Field Goal Percentage': ['.583'],
# ...
